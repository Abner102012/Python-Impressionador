# %% [markdown]
# # Cuidado com o while -> Loop Infinito
#
# Sempre que for usar o comando while, lembre-se de ter certeza que o programa vai terminar em algum momento
#
# ### Exemplo
#
# Digamos que temos uma lista de vendedores e as quantidades vendidas e queremos identificar todos os vendedores que bateram a meta de 50 vendas.

# %%
vendas = [941, 852, 783, 714, 697, 686, 685, 670, 631, 453, 386, 371, 294, 269, 259, 218, 208, 163, 125, 102, 87, 47, 7]
vendedores = ['Maria', 'José', 'Antônio', 'João', 'Francisco', 'Ana', 'Luiz', 'Paulo', 'Carlos', 'Manoel', 'Pedro', 'Francisca', 'Marcos', 'Raimundo', 'Sebastião', 'Antônia', 'Marcelo', 'Jorge', 'Márcia', 'Geraldo', 'Adriana', 'Sandra', 'Luis']
meta = 50

i = 0
while vendas[i] > meta:
    print(f"{vendedores[i]} bateu a meta. Vendendo {vendas[i]}.")
    i += 1
# Out:
# Maria bateu a meta. Vendendo 941.
# José bateu a meta. Vendendo 852.
# Antônio bateu a meta. Vendendo 783.
# João bateu a meta. Vendendo 714.
# Francisco bateu a meta. Vendendo 697.
# Ana bateu a meta. Vendendo 686.
# Luiz bateu a meta. Vendendo 685.
# Paulo bateu a meta. Vendendo 670.
# Carlos bateu a meta. Vendendo 631.
# Manoel bateu a meta. Vendendo 453.
# Pedro bateu a meta. Vendendo 386.
# Francisca bateu a meta. Vendendo 371.
# Marcos bateu a meta. Vendendo 294.
# Raimundo bateu a meta. Vendendo 269.
# Sebastião bateu a meta. Vendendo 259.
# Antônia bateu a meta. Vendendo 218.
# Marcelo bateu a meta. Vendendo 208.
# Jorge bateu a meta. Vendendo 163.
# Márcia bateu a meta. Vendendo 125.
# Geraldo bateu a meta. Vendendo 102.
# Adriana bateu a meta. Vendendo 87.
