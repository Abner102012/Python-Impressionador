# %% [markdown]
# # Adicionar e Remover itens de uma lista

# %% [markdown]
# Adicionar:
# lista.append("item")
#
# Remover:
# item_removido = lista.pop(indice)
# ou
# lista.remove("item")
#
# Digamos que você trabalha e constroi o controle de produtos da Apple.
# E a Apple lançou o Iphone 11 e irá tirar dos seus estoques o Iphone X

# %%
produtos = ["apple tv", "mac", "iphone x", "Ipad", "apple watch", "mac book", "airpods"]
print(produtos)
produtos.append("iphone 11")


produto_remover = "iphonex"
if produto_remover in produtos:
    produtos.remove(produto_remover)
else:
    print(f"{produto_remover} não existe na lista.")

# %% [markdown]
# ### Existem 2 formas de tratar o erro:

# %% [markdown]
# 1. Criar um if para evitar que aconteça.
# 2. Esperar que ele possa acontecer e tratar caso o erro aconteça com:

# %% [markdown]
# try:
#     tentar fazer
# except:
#     caso dê errado

# %%
try:
    produtos.remove("iphonex")
    print(produtos)
except:
    print(f"{produto_remover} não existe na lista.")
