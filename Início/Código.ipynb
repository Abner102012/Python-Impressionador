# %% [markdown]
# # Meu primeiro programa Python
#
# Nesse programa vamos aprender a base inicial de Python

# %%
print("Meu primeiro código")
# Out:
# Meu primeiro código

# %%
print("Mais um código")
# Out:
# Mais um código
