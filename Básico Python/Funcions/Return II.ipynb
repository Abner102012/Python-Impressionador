# %% [markdown]
# # Mais sobre o return
#
# ### Pontos importantes:
#
# - Podemos usar no return praticamente qualquer tipo de objeto: (número, string, lista, tupla, dicionário, outros objetos, etc.)
# - O return, se for executado, encerra a função, mesmo que dentro dela haja um loop.

# %%
#retornar um número
def minha_soma(num1, num2, num3):
    return num1 + num2 + num3

#retornar um texto
def padronizar_texto(texto):
    texto = texto.casefold()
    texto = texto.replace("  ", " ")
    texto = texto.strip()
    return texto

#retornar um boolean
def bateu_meta(vendas, meta):
    if vendas >= meta:
        return True
    else:
        return False
    
#retornar uma lista, tupla ou dicionario
def filtrar_lista_texto(lista, pedaco_texto):
    lista_filtrada = []
    for item in lista:
        if pedaco_texto in item:
            lista_filtrada.append(item)
    return lista_filtrada

# %%
def filtrar_lista_texto(lista, pedaco_texto):
    lista_filtrada = []
    for item in lista:
        if pedaco_texto in item:
            lista_filtrada.append(item)
    return lista_filtrada

lista_textos = [
    "lucas_silva88@gmail.com", "ana.ferreira2024@outlook.com", "marcos_dev_99@hotmail.com",
    "julia.vendas@gmail.com", "roberto.tech@outlook.com", "carla_mkt@hotmail.com",
    "felipe.santos.br@gmail.com", "beatriz_almeida@outlook.com", "andre.lima.oficial@hotmail.com",
    "patricia_rh@gmail.com", "gustavo.ti.cloud@outlook.com", "fernanda_vlog@hotmail.com",
    "ricardo.pinto.82@gmail.com", "gabriela_designer@outlook.com", "tiago.pro@hotmail.com",
    "amanda.costa_26@gmail.com", "bruno_gamer_br@outlook.com", "vanessa.estudos@hotmail.com",
    "diego.oliveira.91@gmail.com", "camila_freelance@outlook.com", "leonardo.mkt.digital@hotmail.com",
    "mariana.souza.dev@gmail.com", "henrique_consultoria@outlook.com", "leticia_med@hotmail.com",
    "paulo.sergio.vendas@gmail.com", "renata_nutri@outlook.com", "igor.automotivo@hotmail.com",
    "sabrina.moda@gmail.com", "vitor_arquitetura@outlook.com", "monica.financas@hotmail.com",
    "caio_edu@gmail.com", "larissa.contabil@outlook.com", "rafael_musica@hotmail.com",
    "daniela_advogada@gmail.com", "marcelo.eng@outlook.com", "aline_estetica@hotmail.com",
    "hugo_santos_it@gmail.com", "priscila.logistica@outlook.com", "fabiola_vendas@hotmail.com",
    "eduardo.lima.dev@gmail.com", "tati_comercial@outlook.com", "willian.tech@hotmail.com",
    "bianca_mkt_2026@gmail.com", "samuel_vendas_sp@outlook.com", "carol.lima.pro@hotmail.com",
    "jorge.augusto@gmail.com", "debora.mendes@outlook.com", "alexandre_ti@hotmail.com",
    "nathalia.gestao@gmail.com", "rodrigo_web@outlook.com", "michele.vendas@hotmail.com",
    "sergio.junior@gmail.com", "elaine_contato@outlook.com", "claudio.farma@hotmail.com",
    "adriana.estilo@gmail.com", "pedro_developer@outlook.com", "simone.eventos@hotmail.com",
    "thiago_suporte@gmail.com", "kelly_mendes@outlook.com", "marcio_imoveis@hotmail.com",
    "clara.nuvem@gmail.com", "fabio_gamer_pro@outlook.com", "isabela.rh.sp@hotmail.com",
    "mateus_tecnico@gmail.com", "barbara.lima@outlook.com", "jonathan_dev@hotmail.com",
    "erica.vendas@gmail.com", "luiz_felipe_85@outlook.com", "danilo_adm@hotmail.com",
    "giselle_nutri@gmail.com", "arthur.santos@outlook.com", "tatiane_edu@hotmail.com",
    "maicon_tech@gmail.com", "regiane.vendas@outlook.com", "douglas_mkt@hotmail.com",
    "viviane.costa@gmail.com", "otavio.dev@outlook.com", "renan_it_solutions@hotmail.com",
    "priscila.mkt.digital@gmail.com", "jeferson_vendas@outlook.com", "milena.adm@hotmail.com",
    "leandro_santos_dev@gmail.com", "andressa_contato@outlook.com", "kleber_pro@hotmail.com",
    "tamires.vendas@gmail.com", "robson_tecnico@outlook.com", "tais.lima.sp@hotmail.com",
    "marcus_vitor@gmail.com", "glaucia_vendas@outlook.com", "cristiano_dev@hotmail.com",
    "veronica.mkt@gmail.com", "sidney_it_pro@outlook.com", "flavia_vlog@hotmail.com",
    "murilo_santos@gmail.com", "rebeca.lima@outlook.com", "wagner_vendas@hotmail.com",
    "cristina.adm@gmail.com", "denis_dev_br@outlook.com", "elisa.mkt@hotmail.com",
    "fabricio_it@gmail.com"
]

lista = filtrar_lista_texto(lista_textos, "gmail")
print(len(lista))
print(lista)
# Out:
# 34
# ['lucas_silva88@gmail.com', 'julia.vendas@gmail.com', 'felipe.santos.br@gmail.com', 'patricia_rh@gmail.com', 'ricardo.pinto.82@gmail.com', 'amanda.costa_26@gmail.com', 'diego.oliveira.91@gmail.com', 'mariana.souza.dev@gmail.com', 'paulo.sergio.vendas@gmail.com', 'sabrina.moda@gmail.com', 'caio_edu@gmail.com', 'daniela_advogada@gmail.com', 'hugo_santos_it@gmail.com', 'eduardo.lima.dev@gmail.com', 'bianca_mkt_2026@gmail.com', 'jorge.augusto@gmail.com', 'nathalia.gestao@gmail.com', 'sergio.junior@gmail.com', 'adriana.estilo@gmail.com', 'thiago_suporte@gmail.com', 'clara.nuvem@gmail.com', 'mateus_tecnico@gmail.com', 'erica.vendas@gmail.com', 'giselle_nutri@gmail.com', 'maicon_tech@gmail.com', 'viviane.costa@gmail.com', 'priscila.mkt.digital@gmail.com', 'leandro_santos_dev@gmail.com', 'tamires.vendas@gmail.com', 'marcus_vitor@gmail.com', 'veronica.mkt@gmail.com', 'murilo_santos@gmail.com', 'cristina.adm@gmail.com', 'fabricio_it@gmail.com']
