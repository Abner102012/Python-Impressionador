# %% [markdown]
# ### Forma que fizemos na aula passada

# %%
faturamento = 1550
custo = 500
lucro = faturamento - custo
print('O faturamento da loja foi ' + str(faturamento))
print("O custo da loja foi de " + str(custo))
print("Assim, o lucro da loja foi de " + str(lucro) + " reais")
# Out:
# O faturamento da loja foi 1550
# O custo da loja foi de 500
# Assim, o lucro da loja foi de 1050 reais

# %% [markdown]
# ### Método format

# %%
faturamento = 1550
custo = 500
lucro = faturamento - custo

print("O faturamento foi de {}. O custo da loja foi de {}. Assim, o lucro da loja foi {}".format(faturamento, custo, lucro))
# Out:
# O faturamento foi de 1550. O custo da loja foi de 500. Assim, o lucro da loja foi 1050
