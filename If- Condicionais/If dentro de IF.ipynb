# %% [markdown]
# # Blocos e identação
# ## Estrutura
# Sempre que usamos o if ou qualquer outra estrutura no Python, devemos usar a identação para dizer para o programa onde a estrutura começa e onde termina.
#
# Isso vai ajudar muito quando tivermos mais de uma condição ao mesmo tempo e quando tivermos várias ações para fazer dentro de um if.

# %% [markdown]
# ### Várias ações em 1 if:

# %% [markdown]
# if condição:
#     alguma coisa
#     outra coisa
#     outra coisa mais
#     outra coisa ainda mais
# else:
#     Uma coisa
#     Uma coisa mais
#     coisa final

# %% [markdown]
# ### Exemplo:
# Vamos fazer um novo exemplo abaixo:
#
# Digamos que você precisa criar um programa para um fundo de investimentos conseguir avaliar o resultado de uma carteira de ações e o quanto de retorno deverá ser pago.
#
# A regra do fundo é:
#
# O fundo se compromete a entregar no mínimo 5% de retorno ao ano.
# Caso o fundo não consiga entregar essa quantia, ele não poderá cobrar taxa de seus investidores.
# Caso o fundo não consiga entregar mais de 5%, ele irá cobrar 2% de taxa de seus investidores.
# Caso o fundo consiga mais de 20% de retorno, ele irá cobrar 4% de taxa dos seus investidores.

# %%
meta = 0.05
taxa = 0
rendimento = 0.01

if rendimento > meta:
    if rendimento > 0.20:
        taxa: 0.04
        print(f"A taxa foi de {taxa:.0%}.")
    else:
        taxa = 0.02
        print(f"A taxa foi de {taxa:.0%}.")

else:
    taxa = 0
    print(f"A taxa foi de {taxa:.0%}")
# Out:
# A taxa foi de 0%

# %% [markdown]
# ### Mais uma condição ao mesmo tempo:

# %% [markdown]
# if condição_1:
#     o que fazer se a condição 1 for verdadeira
#     if condição_2:
#         o que fazer se a condição 1 e 2 for verdadeira
#     else:
#         O que fazer se a condição 2 for falsa mas a 1 é verdadeira
# else:
#      O que fazer se a condição 1 for falsa

# %% [markdown]
# ### Cuidado importante: repetição de código
# Sempre que possível, evite repetir código. De forma geral:
#
# "Se você está repetindo um código, existe uma forma melhor de fazer"
