# %% [markdown]
# # Casos com várias condições/comparações
#
# ### Estrutura:
# Quando temos várias comparações, ao invés de criar if dentro de if podemos usar os operadores "and" e "or" para tratar essas condições.
#
# Funciona assim:

# %% [markdown]
# if condição1 and condição2:
#     vai ser executado se as 2 condições forem verdadeiras ao mesmo tempo
#
# outro caso:
#
# if condição1 or condição2:
#     vai ser executado se pelo menos uma delas é verdadeira

# %% [markdown]
# ### Exemplo
# Vamos voltar ao exemplo do cálculo de meta de vendas dos funcionários. Muitas empresas atribuem bonificação do salário dos funcionários de acordo com o resultado do funcionário e também com o resultado da empresa como um todo.
#
# Nesse caso, a regra funciona assim:
#
# Se o funcionário vendeu mais do que a meta e a loja bateu a meta, o funcionário ganha 3% do que vendeu como bônus.
# Se o funcionário vendeu mais do que a meta e a loja não bateu a meta, o funcionário não ganha bônus

# %%
meta_funcionario = 10000
meta_loja = 250000
vendas_funcionario = 15000
vendas_loja = 220000

if vendas_funcionario > meta_funcionario and vendas_loja > meta_loja:
    bonus = 0.03 * vendas_funcionario
    print(f"Bônus do funcionário foi de {bonus}.")
else:
    print("Funcionário não ganhou bônus.")
# Out:
# Funcionário não ganhou bônus.

# %% [markdown]
# ### Outro exemplo
# Agora vamos levar a análise mais a fundo.
#
# Nessa empresa, existe um outro caso também que garante que o funcionário ganhe um bônus, independente das vendas que ele fez naquele mês.
#
# Todo mês os diretores da empresa fazem uma avaliação qualitativa de todos os funcionários. Nessa avaliação os diretores dão uma nota de 0 a 10 ao funcionário. Se a nota for 9 ou 10, ele ganha 3% de bônus (Os bônus não são cumulativos).

# %%
nota_funcionario = 5
meta_nota = 9

if nota_funcionario >= meta_nota or (vendas_funcionario > meta_funcionario and vendas_loja > meta_loja):
    bonus = 0.03 * vendas_funcionario
    print(f"Bônus do funcionário foi de {bonus}.")
else:
    print("Funcionário não ganha bônus.")
# Out:
# Funcionário não ganha bônus.
